# %%
import pandas as pd

# %%
df = pd.read_csv("../DataSets/CoffeeShopSales-cleaned (1).csv")
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# total_amount        0
# week                0
# weekday             0
# transaction_hour    0
# dtype: int64

# %%
df.dtypes
# Out:
# transaction_id        int64
# transaction_date     object
# transaction_time     object
# transaction_qty       int64
# store_id              int64
# store_location       object
# product_id            int64
# unit_price          float64
# product_category     object
# product_type         object
# product_detail       object
# total_amount        float64
# week                 object
# weekday              object
# transaction_hour      int64
# dtype: object

# %%
df['Month'] = df.transaction_date.str[-5:-3]

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.store_location.unique()
# Out:
# array(['Lower Manhattan', "Hell's Kitchen", 'Astoria'], dtype=object)

# %%
df.product_detail.unique()
# Out:
# array(['Ethiopia Rg', 'Spicy Eye Opener Chai Lg', 'Dark chocolate Lg',
#        'Our Old Time Diner Blend Sm', 'Oatmeal Scone',
#        'Columbian Medium Roast Sm', 'Latte Rg', 'Dark chocolate Rg',
#        'Spicy Eye Opener Chai Rg', 'Ethiopia Lg', 'Earl Grey Lg',
#        'Ouro Brasileiro shot', 'Serenity Green Tea Lg',
#        'Jumbo Savory Scone', 'Lemon Grass Rg',
#        'Sustainably Grown Organic Lg', 'Hazelnut Biscotti', 'Cappuccino',
#        'Lemon Grass Lg', 'Chocolate Chip Biscotti', 'Peppermint Lg',
#        'Chocolate Croissant', 'Latte', 'Brazilian Rg', 'Brazilian Lg',
#        'Columbian Medium Roast Rg', 'Morning Sunrise Chai Rg',
#        'Morning Sunrise Chai Lg', 'Our Old Time Diner Blend Lg',
#        'Sustainably Grown Organic Rg', 'Scottish Cream Scone ',
#        'Peppermint Rg', 'English Breakfast Rg',
#        'Our Old Time Diner Blend Rg', 'Serenity Green Tea Rg',
#        'Brazilian Sm', 'Jamaican Coffee River Sm',
# ...

# %%
df.weekday.value_counts()
# Out:
# weekday
# Friday       21701
# Thursday     21654
# Monday       21643
# Wednesday    21310
# Tuesday      21202
# Sunday       21096
# Saturday     20510
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        transaction_id  transaction_qty       store_id     product_id  \
# count   149116.000000    149116.000000  149116.000000  149116.000000
# mean     74737.371872         1.438276       5.342063      47.918607
# std      43153.600016         0.542509       2.074241      17.930020
# min          1.000000         1.000000       3.000000       1.000000
# 25%      37335.750000         1.000000       3.000000      33.000000
# 50%      74727.500000         1.000000       5.000000      47.000000
# 75%     112094.250000         2.000000       8.000000      60.000000
# max     149456.000000         8.000000       8.000000      87.000000
#
#           unit_price   total_amount  transaction_hour
# count  149116.000000  149116.000000     149116.000000
# mean        3.382219       4.686367         11.735790
# std         2.658723       4.227099          3.764662
# min         0.800000       0.800000          6.000000
# 25%         2.500000       3.000000          9.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                   transaction_id  transaction_qty  store_id  product_id  \
# transaction_id          1.000000         0.010250 -0.006054    0.001076
# transaction_qty         0.010250         1.000000 -0.000794   -0.175255
# store_id               -0.006054        -0.000794  1.000000    0.025727
# product_id              0.001076        -0.175255  0.025727    1.000000
# unit_price              0.000836        -0.123546  0.001891   -0.140423
# total_amount            0.005949         0.356231  0.004595   -0.167461
# transaction_hour       -0.012488        -0.006310 -0.075813   -0.031644
#
#                   unit_price  total_amount  transaction_hour
# transaction_id      0.000836      0.005949         -0.012488
# transaction_qty    -0.123546      0.356231         -0.006310
# store_id            0.001891      0.004595         -0.075813
# product_id         -0.140423     -0.167461         -0.031644
# unit_price          1.000000      0.685550         -0.018435
# ...

# %%
df.groupby('store_location')['total_amount'].sum()
# Out:
# store_location
# Astoria            232243.91
# Hell's Kitchen     236511.17
# Lower Manhattan    230057.25
# Name: total_amount, dtype: float64

# %%
df.groupby('Month')['total_amount'].sum()
# Out:
# Month
# 01     81677.74
# 02     76145.19
# 03     98834.68
# 04    118941.08
# 05    156727.76
# 06    166485.88
# Name: total_amount, dtype: float64

# %%
df.groupby('product_category')['total_amount'].sum()
# Out:
# product_category
# Bakery                 82315.64
# Branded                13607.00
# Coffee                269952.45
# Coffee beans           40085.25
# Drinking Chocolate     72416.00
# Flavours                8408.80
# Loose Tea              11213.60
# Packaged Chocolate      4407.64
# Tea                   196405.95
# Name: total_amount, dtype: float64

# %%
df.groupby('product_category')['total_amount'].sum().nlargest(5)
# Out:
# product_category
# Coffee                269952.45
# Tea                   196405.95
# Bakery                 82315.64
# Drinking Chocolate     72416.00
# Coffee beans           40085.25
# Name: total_amount, dtype: float64

# %%
df.groupby('product_type')['transaction_qty'].sum().nlargest(10)
# Out:
# product_type
# Brewed Chai tea          26250
# Gourmet brewed coffee    25973
# Barista Espresso         24943
# Brewed Black tea         17462
# Hot chocolate            17457
# Brewed herbal tea        17328
# Organic brewed coffee    13012
# Drip coffee              12891
# Premium brewed coffee    12431
# Scone                    10465
# Name: transaction_qty, dtype: int64

# %%
df.groupby('product_type')['transaction_qty'].sum().nsmallest(10)
# Out:
# product_type
# Green beans           134
# Green tea             159
# House blend Beans     183
# Clothing              221
# Organic Chocolate     221
# Drinking Chocolate    266
# Black tea             303
# Herbal tea            305
# Espresso Beans        319
# Gourmet Beans         366
# Name: transaction_qty, dtype: int64

# %%
df.groupby('weekday')['total_amount'].mean()
# Out:
# weekday
# Friday       4.671352
# Monday       4.697929
# Saturday     4.724255
# Sunday       4.661088
# Thursday     4.653541
# Tuesday      4.690875
# Wednesday    4.707346
# Name: total_amount, dtype: float64

# %%
pd.pivot_table(df,index='product_category',columns='store_location',values='total_amount',aggfunc ='sum',margins = True)
# Out:
# store_location        Astoria  Hell's Kitchen  Lower Manhattan        All
# product_category
# Bakery               26599.75        27386.95         28328.94   82315.64
# Branded               5457.00         1942.00          6208.00   13607.00
# Coffee               89744.30        91222.65         88985.50  269952.45
# Coffee beans         10219.20        18635.10         11230.95   40085.25
# Drinking Chocolate   26335.25        23586.25         22494.50   72416.00
# Flavours              1764.80         2876.80          3767.20    8408.80
# Loose Tea             3194.00         4461.35          3558.25   11213.60
# Packaged Chocolate    1089.71         1698.77          1619.16    4407.64
# Tea                  67839.90        64701.30         63864.75  196405.95
# All                 232243.91       236511.17        230057.25  698812.33

# %%
pd.pivot_table(df,index='weekday',columns='store_location',values='total_amount',aggfunc ='sum',margins = True)
# Out:
# store_location    Astoria  Hell's Kitchen  Lower Manhattan        All
# weekday
# Friday           33472.75        34743.18         33157.07  101373.00
# Monday           33928.29        33389.51         34359.48  101677.28
# Saturday         31845.93        32599.23         32449.32   96894.48
# Sunday           32795.18        33685.63         31849.50   98330.31
# Thursday         34140.37        33468.06         33159.35  100767.78
# Tuesday          31816.76        34846.47         32792.71   99455.94
# Wednesday        34244.63        33779.09         32289.82  100313.54
# All             232243.91       236511.17        230057.25  698812.33

# %%
pd.pivot_table(df,index='product_type',columns='product_category',values='transaction_qty',aggfunc ='sum',margins = True)
# Out:
# product_category        Bakery  Branded   Coffee  Coffee beans  \
# product_type
# Barista Espresso           NaN      NaN  24943.0           NaN
# Biscotti                5788.0      NaN      NaN           NaN
# Black tea                  NaN      NaN      NaN           NaN
# Brewed Black tea           NaN      NaN      NaN           NaN
# Brewed Chai tea            NaN      NaN      NaN           NaN
# Brewed Green tea           NaN      NaN      NaN           NaN
# Brewed herbal tea          NaN      NaN      NaN           NaN
# Chai tea                   NaN      NaN      NaN           NaN
# Clothing                   NaN    221.0      NaN           NaN
# Drinking Chocolate         NaN      NaN      NaN           NaN
# Drip coffee                NaN      NaN  12891.0           NaN
# Espresso Beans             NaN      NaN      NaN         319.0
# Gourmet Beans              NaN      NaN      NaN         366.0
# Gourmet brewed coffee      NaN      NaN  25973.0           NaN
# ...

# %%
pd.pivot_table(df,index='Month',columns='product_category',values='transaction_qty',aggfunc ='sum',margins = True)
# Out:
# product_category  Bakery  Branded  Coffee  Coffee beans  Drinking Chocolate  \
# Month
# 01                  2690      100   10355           234                2015
# 02                  2559       74    9689           195                1964
# 03                  3358      104   12604           251                2475
# 04                  3951      142   15210           310                2952
# 05                  5225      161   19948           407                3930
# 06                  5431      195   21444           431                4121
# All                23214      776   89250          1828               17457
#
# product_category  Flavours  Loose Tea  Packaged Chocolate    Tea     All
# Month
# 01                    1218        141                  57   8060   24870
# 02                    1163        137                  51   7718   23550
# 03                    1465        178                  65   9906   30406
# ...

# %%
print(df.store_location.unique())
s = input("Enter store_location name:")
ss = df[df.store_location == s]

print(ss.product_category.unique())
p = input("Enter product_category name:")
pp = df[df.product_category == s]

a= pp.groupby('product_type')['total_amount'].sum()
# Out:
# ['Lower Manhattan' "Hell's Kitchen" 'Astoria']
# Enter store_location name: Hell's Kitchen
# ['Tea' 'Drinking Chocolate' 'Coffee' 'Bakery' 'Flavours' 'Coffee beans'
#  'Loose Tea' 'Packaged Chocolate' 'Branded']
# Enter product_category name: Coffee

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
sb.countplot(x = df.store_location)
plt.show()

# %%
sb.barplot(x=df.store_location , y=df.total_amount)
plt.show()

# %%
sb.barplot(x=df.product_category , y=df.total_amount)
plt.xticks(rotation = 90)
plt.show()

# %%
df.groupby('product_category')['transaction_qty'].sum()
sb.barplot(x=df.product_category, y=df.transaction_qty)
plt.xticks(rotation=90)
plt.show()

# %%
sb.lineplot(x=df.weekday, y=df.total_amount)
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby('Month')['total_amount'].sum()
sb.lineplot(x=df.weekday, y=df.total_amount)
plt.xticks(rotation=90)
plt.show()

# %%
a=df.groupby('product_category')['total_amount'].sum()
plt.pie(a.values,labels=a.index,autopct='%d%%')
plt.figure(figsize=(15,12))
plt.show()

# %%
b=df.groupby('store_location')['total_amount'].sum()
plt.pie(b.values,labels=b.index,autopct='%d%%')
plt.figure(figsize=(15,12))
plt.show()

# %%
f=df.groupby('weekday')['total_amount'].sum()
plt.pie(f.values,labels=f.index,autopct='%d%%')
plt.figure(figsize=(15,12))
plt.show()

# %%
sb.histplot(df.total_amount,bins=3)
plt.show()

# %%
sb.histplot(df.transaction_qty,bins=10)
plt.show()

# %%
sb.histplot(df.unit_price,bins=10)
plt.show()

# %%
sb.pointplot(x=df.product_category, y=df.total_amount)
plt.xticks(rotation=90)
plt.show()

# %%
sb.pointplot(x=df.store_location, y=df.total_amount)
plt.xticks(rotation=90)
plt.show()

# %%
total_sales=df.groupby('product_category')['total_amount'].sum()
sb.stripplot(total_sales)
plt.show()

# %%
sb.violinplot(df.total_amount)
plt.show()

# %%
sb.violinplot(df.unit_price)
plt.show()

# %%
sb.swarmplot(df.transaction_qty)
plt.show()

# %%
sb.swarmplot(df.unit_price)
plt.show()

# %%
plt.scatter(df.unit_price,df.transaction_qty)
plt.show()

# %%
sb.pairplot(df[['unit_price','total_amount','transaction_qty']])
plt.show()

# %%
sb.jointplot(x=df.unit_price, y=df.total_amount)
plt.show()

# %%
sb.jointplot(x=df.transaction_qty, y=df.total_amount)
plt.show()

# %%
sb.kdeplot(df.total_amount)
plt.show()

# %%
sb.kdeplot(df.transaction_qty)
plt.show()
